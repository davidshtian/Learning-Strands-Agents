# %% [markdown]
# # Chapter 7: Monitoring and Observability in Strands Agents
#
# ## Introduction to Agent Observability
#
# As you deploy Strands Agents into production environments, understanding how they're performing, debugging issues, and ensuring reliable operation becomes critical. This chapter focuses on monitoring and observability techniques for Strands Agents, helping you build reliable AI systems that can be effectively maintained in production.
#
# We'll cover:
# - Logging full lifecycle actions
# - Monitoring performance and latency
# - Tracing agent operations
#
# As with previous chapters, we'll use the Nova Lite model (`us.amazon.nova-lite-v1:0`) as specified for our course.

# %% [markdown]
# ## Setup and Prerequisites
#
# Let's start by installing the necessary packages:

# %%
# %pip install -U strands-agents strands-agents-tools
# %pip install -U matplotlib
# Out:
# Requirement already satisfied: strands-agents in /home/ubuntu/mydev/lib/python3.12/site-packages (0.2.1)
# Requirement already satisfied: strands-agents-tools in /home/ubuntu/mydev/lib/python3.12/site-packages (0.1.8)
# Requirement already satisfied: boto3<2.0.0,>=1.26.0 in /home/ubuntu/mydev/lib/python3.12/site-packages (from strands-agents) (1.38.36)
# Requirement already satisfied: botocore<2.0.0,>=1.29.0 in /home/ubuntu/mydev/lib/python3.12/site-packages (from strands-agents) (1.38.36)
# Requirement already satisfied: docstring-parser<1.0,>=0.15 in /home/ubuntu/mydev/lib/python3.12/site-packages (from strands-agents) (0.15)
# Requirement already satisfied: mcp<2.0.0,>=1.8.0 in /home/ubuntu/mydev/lib/python3.12/site-packages (from strands-agents) (1.9.4)
# Requirement already satisfied: opentelemetry-api<2.0.0,>=1.30.0 in /home/ubuntu/mydev/lib/python3.12/site-packages (from strands-agents) (1.34.1)
# Requirement already satisfied: opentelemetry-sdk<2.0.0,>=1.30.0 in /home/ubuntu/mydev/lib/python3.12/site-packages (from strands-agents) (1.34.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /home/ubuntu/mydev/lib/python3.12/site-packages (from strands-agents) (2.11.7)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.13.2 in /home/ubuntu/mydev/lib/python3.12/site-packages (from strands-agents) (4.14.0)
# Requirement already satisfied: watchdog<7.0.0,>=6.0.0 in /home/ubuntu/mydev/lib/python3.12/site-packages (from strands-agents) (6.0.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/ubuntu/mydev/lib/python3.12/site-packages (from boto3<2.0.0,>=1.26.0->strands-agents) (1.0.1)
# Requirement already satisfied: s3transfer<0.14.0,>=0.13.0 in /home/ubuntu/mydev/lib/python3.12/site-packages (from boto3<2.0.0,>=1.26.0->strands-agents) (0.13.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/ubuntu/mydev/lib/python3.12/site-packages (from botocore<2.0.0,>=1.29.0->strands-agents) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /home/ubuntu/mydev/lib/python3.12/site-packages (from botocore<2.0.0,>=1.29.0->strands-agents) (2.4.0)
# Requirement already satisfied: anyio>=4.5 in /home/ubuntu/mydev/lib/python3.12/site-packages (from mcp<2.0.0,>=1.8.0->strands-agents) (4.9.0)
# Requirement already satisfied: httpx-sse>=0.4 in /home/ubuntu/mydev/lib/python3.12/site-packages (from mcp<2.0.0,>=1.8.0->strands-agents) (0.4.0)
# Requirement already satisfied: httpx>=0.27 in /home/ubuntu/mydev/lib/python3.12/site-packages (from mcp<2.0.0,>=1.8.0->strands-agents) (0.28.1)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /home/ubuntu/mydev/lib/python3.12/site-packages (from mcp<2.0.0,>=1.8.0->strands-agents) (2.9.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /home/ubuntu/mydev/lib/python3.12/site-packages (from mcp<2.0.0,>=1.8.0->strands-agents) (0.0.20)
# Requirement already satisfied: sse-starlette>=1.6.1 in /home/ubuntu/mydev/lib/python3.12/site-packages (from mcp<2.0.0,>=1.8.0->strands-agents) (2.3.6)
# Requirement already satisfied: starlette>=0.27 in /home/ubuntu/mydev/lib/python3.12/site-packages (from mcp<2.0.0,>=1.8.0->strands-agents) (0.47.0)
# Requirement already satisfied: uvicorn>=0.23.1 in /home/ubuntu/mydev/lib/python3.12/site-packages (from mcp<2.0.0,>=1.8.0->strands-agents) (0.34.3)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /home/ubuntu/mydev/lib/python3.12/site-packages (from opentelemetry-api<2.0.0,>=1.30.0->strands-agents) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in /home/ubuntu/mydev/lib/python3.12/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api<2.0.0,>=1.30.0->strands-agents) (3.23.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.55b1 in /home/ubuntu/mydev/lib/python3.12/site-packages (from opentelemetry-sdk<2.0.0,>=1.30.0->strands-agents) (0.55b1)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/ubuntu/mydev/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->strands-agents) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /home/ubuntu/mydev/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->strands-agents) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/ubuntu/mydev/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->strands-agents) (0.4.1)
# Requirement already satisfied: six>=1.5 in /home/ubuntu/mydev/lib/python3.12/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<2.0.0,>=1.29.0->strands-agents) (1.17.0)
# Requirement already satisfied: aws-requests-auth<0.5.0,>=0.4.3 in /home/ubuntu/mydev/lib/python3.12/site-packages (from strands-agents-tools) (0.4.3)
# Requirement already satisfied: colorama<0.5.0,>=0.4.6 in /home/ubuntu/mydev/lib/python3.12/site-packages (from strands-agents-tools) (0.4.6)
# Requirement already satisfied: dill<0.5.0,>=0.4.0 in /home/ubuntu/mydev/lib/python3.12/site-packages (from strands-agents-tools) (0.4.0)
# Requirement already satisfied: pillow<12.0.0,>=11.2.1 in /home/ubuntu/mydev/lib/python3.12/site-packages (from strands-agents-tools) (11.2.1)
# Requirement already satisfied: prompt-toolkit<4.0.0,>=3.0.51 in /home/ubuntu/mydev/lib/python3.12/site-packages (from strands-agents-tools) (3.0.51)
# Requirement already satisfied: pyjwt<3.0.0,>=2.10.1 in /home/ubuntu/mydev/lib/python3.12/site-packages (from strands-agents-tools) (2.10.1)
# Requirement already satisfied: rich<15.0.0,>=14.0.0 in /home/ubuntu/mydev/lib/python3.12/site-packages (from strands-agents-tools) (14.0.0)
# Requirement already satisfied: slack-bolt<2.0.0,>=1.23.0 in /home/ubuntu/mydev/lib/python3.12/site-packages (from strands-agents-tools) (1.23.0)
# Requirement already satisfied: sympy<2.0.0,>=1.12.0 in /home/ubuntu/mydev/lib/python3.12/site-packages (from strands-agents-tools) (1.14.0)
# Requirement already satisfied: tenacity<10.0.0,>=9.1.2 in /home/ubuntu/mydev/lib/python3.12/site-packages (from strands-agents-tools) (9.1.2)
# Requirement already satisfied: requests>=0.14.0 in /home/ubuntu/mydev/lib/python3.12/site-packages (from aws-requests-auth<0.5.0,>=0.4.3->strands-agents-tools) (2.32.4)
# Requirement already satisfied: wcwidth in /home/ubuntu/mydev/lib/python3.12/site-packages (from prompt-toolkit<4.0.0,>=3.0.51->strands-agents-tools) (0.2.13)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/ubuntu/mydev/lib/python3.12/site-packages (from rich<15.0.0,>=14.0.0->strands-agents-tools) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/ubuntu/mydev/lib/python3.12/site-packages (from rich<15.0.0,>=14.0.0->strands-agents-tools) (2.19.1)
# Requirement already satisfied: slack_sdk<4,>=3.35.0 in /home/ubuntu/mydev/lib/python3.12/site-packages (from slack-bolt<2.0.0,>=1.23.0->strands-agents-tools) (3.35.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/ubuntu/mydev/lib/python3.12/site-packages (from sympy<2.0.0,>=1.12.0->strands-agents-tools) (1.3.0)
# Requirement already satisfied: idna>=2.8 in /home/ubuntu/mydev/lib/python3.12/site-packages (from anyio>=4.5->mcp<2.0.0,>=1.8.0->strands-agents) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /home/ubuntu/mydev/lib/python3.12/site-packages (from anyio>=4.5->mcp<2.0.0,>=1.8.0->strands-agents) (1.3.1)
# Requirement already satisfied: certifi in /home/ubuntu/mydev/lib/python3.12/site-packages (from httpx>=0.27->mcp<2.0.0,>=1.8.0->strands-agents) (2025.6.15)
# Requirement already satisfied: httpcore==1.* in /home/ubuntu/mydev/lib/python3.12/site-packages (from httpx>=0.27->mcp<2.0.0,>=1.8.0->strands-agents) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/ubuntu/mydev/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.27->mcp<2.0.0,>=1.8.0->strands-agents) (0.16.0)
# Requirement already satisfied: mdurl~=0.1 in /home/ubuntu/mydev/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich<15.0.0,>=14.0.0->strands-agents-tools) (0.1.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /home/ubuntu/mydev/lib/python3.12/site-packages (from pydantic-settings>=2.5.2->mcp<2.0.0,>=1.8.0->strands-agents) (1.1.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/ubuntu/mydev/lib/python3.12/site-packages (from requests>=0.14.0->aws-requests-auth<0.5.0,>=0.4.3->strands-agents-tools) (3.4.2)
# Requirement already satisfied: click>=7.0 in /home/ubuntu/mydev/lib/python3.12/site-packages (from uvicorn>=0.23.1->mcp<2.0.0,>=1.8.0->strands-agents) (8.2.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in /home/ubuntu/mydev/lib/python3.12/site-packages (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/ubuntu/mydev/lib/python3.12/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/ubuntu/mydev/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ubuntu/mydev/lib/python3.12/site-packages (from matplotlib) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/ubuntu/mydev/lib/python3.12/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /home/ubuntu/mydev/lib/python3.12/site-packages (from matplotlib) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in /home/ubuntu/mydev/lib/python3.12/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /home/ubuntu/mydev/lib/python3.12/site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/ubuntu/mydev/lib/python3.12/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/ubuntu/mydev/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/ubuntu/mydev/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Logging
#
# Strands Agents provide built-in capabilities for logging agent operations. Let's start with some basic logging approaches:

# %%
import logging

# Configure the root strands logger
logging.getLogger("strands").setLevel(logging.DEBUG)

# %%
from strands import Agent, tool
from strands_tools import current_time, calculator
# Create a simple agent
simple_agent = Agent(
    model="us.amazon.nova-lite-v1:0",  # Using Nova Lite model
    tools=[current_time],
    system_prompt="You are a helpful assistant that provides clear and informative responses."
)

result = simple_agent("What's the time in London?")
# Out:
# DEBUG | strands.models.bedrock | config=<{'model_id': 'us.amazon.nova-lite-v1:0'}> | initializing
# DEBUG | strands.models.bedrock | region=<us-east-1> | bedrock client created
# DEBUG | strands.tools.registry | tool_name=<current_time>, tool_type=<function>, is_dynamic=<False> | registering tool
# DEBUG | strands.tools.registry | tools_dir=</home/ubuntu/Learning-Strands-Agents/07_observability/tools> | tools directory not found
# DEBUG | strands.tools.registry | tool_modules=<[]> | discovered
# DEBUG | strands.tools.registry | tool_count=<0>, success_count=<0> | finished loading tools
# DEBUG | strands.tools.registry | tools_dir=</home/ubuntu/Learning-Strands-Agents/07_observability/tools> | tools directory not found
# DEBUG | strands.tools.registry | getting tool configurations
# DEBUG | strands.tools.registry | tool_name=<current_time> | loaded tool config
# DEBUG | strands.tools.registry | tool_count=<1> | tools configured
# DEBUG | strands.tools.registry | getting tool configurations
# DEBUG | strands.tools.registry | tool_name=<current_time> | loaded tool config
# DEBUG | strands.tools.registry | tool_count=<1> | tools configured
# DEBUG | strands.event_loop.streaming | model=<<strands.models.bedrock.BedrockModel object at 0x7561c8322f90>> | streaming messages
# DEBUG | strands.types.models.model | formatting request
# DEBUG | strands.types.models.model | formatted request=<{'modelId': 'us.amazon.nova-lite-v1:0', 'messages': [{'role': 'user', 'content': [{'text': "What's the time in London?"}]}], 'system': [{'text': 'You are a helpful assistant that provides clear and informative responses.'}], 'toolConfig': {'tools': [{'toolSpec': {'name': 'current_time', 'description': 'Get the current time in ISO 8601 format.\n\nThis tool returns the current date and time in ISO 8601 format (e.g., 2023-04-15T14:32:16.123456+00:00)\nfor the specified timezone. If no timezone is provided, the value from the DEFAULT_TIMEZONE\nenvironment variable is used (defaults to \'UTC\' if not set).\n\nArgs:\n    timezone (str, optional): The timezone to use (e.g., \'UTC\', \'US/Pacific\', \'Europe/London\', \'Asia/Tokyo\').\n        Defaults to environment variable DEFAULT_TIMEZONE (\'UTC\' if not set).\n\nReturns:\n    str: The current time in ISO 8601 format.\n\nRaises:\n    ValueError: If an invalid timezone is provided.\n\nExamples:\n    >>> current_time()  # Returns current time in default timezone (from DEFAULT_TIMEZONE or UTC)\n    \'2023-04-15T14:32:16.123456+00:00\'\n\n    >>> current_time(timezone="US/Pacific")  # Returns current time in Pacific timezone\n    \'2023-04-15T07:32:16.123456-07:00\'', 'inputSchema': {'json': {'properties': {'timezone': {'default': None, 'description': "The timezone to use (e.g., 'UTC', 'US/Pacific', 'Europe/London', 'Asia/Tokyo').\nDefaults to environment variable DEFAULT_TIMEZONE ('UTC' if not set).", 'type': 'string'}}, 'type': 'object', 'required': []}}}}], 'toolChoice': {'auto': {}}}, 'inferenceConfig': {}}>
# DEBUG | strands.types.models.model | invoking model
# DEBUG | strands.types.models.model | got response from model
# <thinking> The User has asked for the current time in London. I can use the `current_time`
# DEBUG | strands.types.models.model | finished streaming response from model
# DEBUG | strands.tools.executor | tool_count=<1> | executing tools in parallel
# DEBUG | strands.handlers.tool_handler | tool=<{'toolUseId': 'tooluse_E9Gpf6iUSpu3PDGAHvZD4w', 'name': 'current_time', 'input': {'timezone': 'Europe/London'}}> | invoking
# DEBUG | strands.tools.executor | tool_count=<1> | submitted tasks to parallel executor
# DEBUG | strands.event_loop.streaming | model=<<strands.models.bedrock.BedrockModel object at 0x7561c8322f90>> | streaming messages
# DEBUG | strands.types.models.model | formatting request
# DEBUG | strands.types.models.model | formatted request=<{'modelId': 'us.amazon.nova-lite-v1:0', 'messages': [{'role': 'user', 'content': [{'text': "What's the time in London?"}]}, {'role': 'assistant', 'content': [{'text': '<thinking> The User has asked for the current time in London. I can use the `current_time` tool to retrieve this information, specifying the timezone as "Europe/London". </thinking>\n'}, {'toolUse': {'toolUseId': 'tooluse_E9Gpf6iUSpu3PDGAHvZD4w', 'name': 'current_time', 'input': {'timezone': 'Europe/London'}}}]}, {'role': 'user', 'content': [{'toolResult': {'toolUseId': 'tooluse_E9Gpf6iUSpu3PDGAHvZD4w', 'status': 'success', 'content': [{'text': '2025-07-08T10:46:29.341849+01:00'}]}}]}], 'system': [{'text': 'You are a helpful assistant that provides clear and informative responses.'}], 'toolConfig': {'tools': [{'toolSpec': {'name': 'current_time', 'description': 'Get the current time in ISO 8601 format.\n\nThis tool returns the current date and time in ISO 8601 format (e.g., 2023-04-15T14:32:16.123456+00:00)\nfor the specified timezone. If no timezone is provided, the value from the DEFAULT_TIMEZONE\nenvironment variable is used (defaults to \'UTC\' if not set).\n\nArgs:\n    timezone (str, optional): The timezone to use (e.g., \'UTC\', \'US/Pacific\', \'Europe/London\', \'Asia/Tokyo\').\n        Defaults to environment variable DEFAULT_TIMEZONE (\'UTC\' if not set).\n\nReturns:\n    str: The current time in ISO 8601 format.\n\nRaises:\n    ValueError: If an invalid timezone is provided.\n\nExamples:\n    >>> current_time()  # Returns current time in default timezone (from DEFAULT_TIMEZONE or UTC)\n    \'2023-04-15T14:32:16.123456+00:00\'\n\n    >>> current_time(timezone="US/Pacific")  # Returns current time in Pacific timezone\n    \'2023-04-15T07:32:16.123456-07:00\'', 'inputSchema': {'json': {'properties': {'timezone': {'default': None, 'description': "The timezone to use (e.g., 'UTC', 'US/Pacific', 'Europe/London', 'Asia/Tokyo').\nDefaults to environment variable DEFAULT_TIMEZONE ('UTC' if not set).", 'type': 'string'}}, 'type': 'object', 'required': []}}}}], 'toolChoice': {'auto': {}}}, 'inferenceConfig': {}}>
# DEBUG | strands.types.models.model | invoking model
# DEBUG | strands.types.models.model | got response from model
#  tool to retrieve this information, specifying the timezone as "Europe/London". </thinking>
#
# Tool #1: current_time
# <thinking> I have retrieved the current time in London using the `current_time` tool. The result is in ISO 8601 format and includes the timezone offset. </thinking>
#
# The current time in London is **2025-07-08T10:4
# DEBUG | strands.types.models.model | finished streaming response from model
# DEBUG | strands.agent.conversation_manager.sliding_window_conversation_manager | window_size=<4>, message_count=<40> | skipping context reduction
# 6:29.341849+01:00**.

# %%
# Add a handler to see the logs
logging.basicConfig(
    format="%(levelname)s | %(name)s | %(message)s", 
    handlers=[logging.StreamHandler()],
    force=True
)

# %%
class AgentObservabilityMiddleware:
    def __init__(self):
        self.metrics = {
            "total_calls": 0,
            "total_tool_calls": 0,
            "total_errors": 0,
            "total_execution_time": 0,
            "tool_usage": {}
        }
    
    def __call__(self, next_handler):
        def handle(agent_instance, query, **kwargs):
            # Pre-processing
            self.metrics["total_calls"] += 1
            start_time = time.time()
            
            try:
                # Execute the agent
                response = next_handler(agent_instance, query, **kwargs)
                
                # Post-processing
                execution_time = time.time() - start_time
                self.metrics["total_execution_time"] += execution_time
                
                # Track tool usage
                tool_calls = getattr(response, 'tool_calls', [])
                self.metrics["total_tool_calls"] += len(tool_calls)
                
                for call in tool_calls:
                    tool_name = call.tool_name
                    if tool_name not in self.metrics["tool_usage"]:
                        self.metrics["tool_usage"][tool_name] = 0
                    self.metrics["tool_usage"][tool_name] += 1
                
                return response
                
            except Exception as e:
                self.metrics["total_errors"] += 1
                raise
        
        return handle
    
    def get_metrics(self):
        # Calculate average execution time
        avg_time = 0
        if self.metrics["total_calls"] > 0:
            avg_time = self.metrics["total_execution_time"] / self.metrics["total_calls"]
        
        # Add calculated metrics
        metrics = self.metrics.copy()
        metrics["average_execution_time"] = avg_time
        metrics["error_rate"] = self.metrics["total_errors"] / max(1, self.metrics["total_calls"])
        
        return metrics

# %% [markdown]
# Let's test our middleware with a Strands Agent:

# %%
# Create a custom tool for testing
@tool
def weather_info(location: str) -> str:
    """Get weather information for a specified location."""
    # Mock data for demonstration
    weather_data = {
        "new york": "72°F, Partly Cloudy",
        "london": "64°F, Rainy",
        "tokyo": "78°F, Sunny",
        "sydney": "70°F, Clear",
        "paris": "68°F, Cloudy"
    }
    return weather_data.get(location.lower(), "Weather information not available")

# Create an observable agent
middleware = AgentObservabilityMiddleware()
observable_agent = Agent(
    model="us.amazon.nova-pro-v1:0",
    tools=[calculator, weather_info],
    system_prompt="You are a helpful assistant that can check weather and perform calculations.",
    middleware=[middleware]
)

# Run some test queries
queries = [
    "What's the weather like in Tokyo?",
    "Calculate 573 * 218",
    "What's the weather in Paris and how much is 100 * 1.2?"
]

for query in queries:
    print(f"\nQuery: {query}")
    response = observable_agent(query)
    print(f"Response: {response.message}")

# Show the collected metrics
print("\n\nAgent Metrics:")
import json
print(json.dumps(middleware.get_metrics(), indent=2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 19
#      15 # Create an observable agent
#      16 middleware = AgentObservabilityMiddleware()
#      17 observable_agent = Agent(
#      18     model="us.amazon.nova-pro-v1:0",
# ---> 19     tools=[calculator, weather_info],
#      20     system_prompt="You are a helpful assistant that can check weather and perform calculations.",
#      21     middleware=[middleware]
#      22 )
#      24 # Run some test queries
#      25 queries = [
#      26     "What's the weather like in Tokyo?",
#      27     "Calculate 573 * 218",
#      28     "What's the weather in Paris and how much is 100 * 1.2?"
#      29 ]
#
# NameError: name 'calculator' is not defined

# %%
from strands.handlers.callback_handler import PrintingCallbackHandler

# Create a simple agent
simple_agent = Agent(
    model="us.amazon.nova-lite-v1:0",  # Using Nova Lite model
    tools=[current_time],
    system_prompt="You are a helpful assistant that provides clear and informative responses."
)

result = simple_agent("What's the time in London?")

# %% [markdown]
# ### Callback Handler
# The Strands Agents SDK provides two "process present" mechanisms:
#
# - **Standard logging**: For internal operations, debugging, and errors (primarily for developers)
# - **Callback system**: For user-facing output, streaming responses, and tool execution notifications
#
# Callbacks are configured through the callback_handler parameter when creating an Agent object. You can use built-in handlers (`PrintingCallbackHandler` by default), or create custom callback handlers to process streaming events according to your application's specific requirements.

# %%
import logging

# Configure the root strands logger
logging.getLogger("strands").setLevel(logging.INFO)

# %%
simple_agent = Agent(
    model="us.amazon.nova-lite-v1:0",  # Using Nova Lite model
    tools=[current_time],
    system_prompt="You are a helpful assistant that provides clear and informative responses.",
    callback_handler=PrintingCallbackHandler()
)

result = simple_agent("What's the time in London?")

# %%
simple_agent = Agent(
    model="us.amazon.nova-lite-v1:0",  # Using Nova Lite model
    tools=[current_time],
    system_prompt="You are a helpful assistant that provides clear and informative responses.",
    callback_handler=None
)

result = simple_agent("What's the time in London?")

# %%
print(result)

# %% [markdown]
# ## Monitoring
# By default, Strands Agents provides you complete metrics to track and analyze your agent's performance. These metrics are automatically collected and can be accessed after agent execution. This data helps you optimize your agent's performance, monitor resource usage, and control operational costs without requiring any additional configuration.
#
# You can access these metrics programmatically to integrate with your monitoring systems or to generate performance reports for your application.

# %%
import pprint
pprint.pprint(result.metrics.get_summary())

# %% [markdown]
# ### Tracking Token Usage and Costs
#
# For production systems, monitoring token usage and costs is critical.

# %%
result.metrics.accumulated_usage

# %% [markdown]
# ## Tracing
#
# Observability relies heavily on tracing to offer in-depth visibility into your agent's operations. By adhering to the OpenTelemetry standard, Strands Agents framework traces meticulously record the entire path of a request as it moves through your agent. This includes interactions with LLMs, data retrieval processes, tool utilization, and the handling of events within the loop.
#
# <img src="jeager.jpg" width="750" alt="jeager">
#
# (image using Jeager)

# %%
# Pull and run Jaeger all-in-one container
# Suppose you've install docker
# !sudo docker run -d --name jaeger \
  -e COLLECTOR_ZIPKIN_HOST_PORT=:9411 \
  -e COLLECTOR_OTLP_ENABLED=true \
  -p 6831:6831/udp \
  -p 6832:6832/udp \
  -p 5778:5778 \
  -p 16686:16686 \
  -p 4317:4317 \
  -p 4318:4318 \
  -p 14250:14250 \
  -p 14268:14268 \
  -p 14269:14269 \
  -p 9411:9411 \
  jaegertracing/all-in-one:latest

# %%
import os
from strands.telemetry.tracer import get_tracer

# Configure the tracer
tracer = get_tracer(
    service_name="strands-agents-svc",
    otlp_endpoint="http://localhost:4318",
    otlp_headers={"Authorization": "Bearer TOKEN"},
    enable_console_export=True
)

# Create agent
agent = Agent(
    model="us.amazon.nova-lite-v1:0",
    tools=[current_time],
    system_prompt="You are a helpful assistant that provides clear and informative responses."
)

# Execute a series of interactions that will be traced
response = agent("Hi!")
print(response)

# Ask a follow-up that uses tools
response = agent("What's the time in London?")
print(response)

# Each interaction creates a complete trace that can be visualized in your tracing tool

# %% [markdown]
# ## Best Practices for Agent Observability
#
# When implementing observability for your Strands Agents, consider these best practices:
#
# 1. Standardize instrumentation using OpenTelemetry
# 2. Design for multiple consumers using fan-out architecture
# 3. Optimize large data volume through filtering and sampling
# 4. Shift observability left during agent development
#
# These practices should be implemented from day one to ensure reliable agent performance.

# %% [markdown]
# ## Summary
#
# In this chapter, we've explored various approaches to monitoring and observability for Strands Agents:
#
# 1. Basic logging techniques for tracking agent activity
# 2. Tracking token usage and costs
# 3. Agent monitoring
# 4. Tracing
#
# These techniques allow you to maintain visibility into how your agents are performing in production, identify issues early, and ensure cost-effective operation. As your agent systems grow in complexity, a robust observability strategy becomes increasingly important.

# %% [markdown]
# ## Exercises
#
# 1. Create a visualization that shows the distribution of response times for an agent over multiple requests
# 2. Build a simple web dashboard (using a library like Dash or Streamlit) to display agent metrics in real-time
# 3. Implement a token budget system that can automatically pause agent operations when a daily token limit is reached

# %% [markdown]
# ## Ending
#
# This concludes our course on Strands Agents. We've covered everything from the basics of creating agents, to using tools, customizing functionality, integrating with MCP, deploying to production, and building multi-agent systems. With the knowledge from all chapters in this course, you now have a comprehensive understanding of building, deploying, monitoring, and optimizing AI agents with the Strands Agents framework.
#
# 🎉🎉🎉
